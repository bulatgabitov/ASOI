# %% [markdown]
# <a href="https://colab.research.google.com/github/yustinaivanova/netology_statistics/blob/master/dz_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Материалы Юстины Ивановой: https://github.com/yustinaivanova/netology_statistics_february_20

# %% [markdown]
# # Домашняя работа №3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
# %matplotlib inline
import statistics

# %% [markdown]
# Загрузить датасет по url:

# %%
import ssl
# следующая строчка подключает сертификат для защищенного соединения
ssl._create_default_https_context = ssl._create_unverified_context
# все данные загружаются с сервера
url="http://yustiks.ru/dataset/world-happiness-report-2019.csv"
df=pd.read_csv(url)

# %%
df.head()
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# 1                      23.0
# 2                      12.0
# 3                      13.0
# 4                      18.0

# %% [markdown]
# Более подробно о датасете можно прочитать по [данной ссылке](https://data.world/promptcloud/world-happiness-report-2019) или по [ссылке в kaggle](https://www.kaggle.com/PromptCloudHQ/world-happiness-report-2019)

# %% [markdown]
# Context
#
# The World Happiness Report is a landmark survey of the state of global happiness that ranks 156 countries by how happy their citizens perceive themselves to be. This year’s World Happiness Report focuses on happiness and the community: how happiness has evolved over the past dozen years, with a focus on the technologies, social norms, conflicts and government policies that have driven those changes.

# %% [markdown]
# *  **Country (region)** Name of the country.
# *  **Ladder** Cantril Ladder is a measure of life satisfaction.
# *  **SD of Ladder** Standard deviation of the ladder.
# *  **Positive affect** Measure of positive emotion.
# *  **Negative affect** Measure of negative emotion.
# *  **Social support** The extent to which Social support contributed to the calculation of the Happiness Score.
# *  **Freedom** The extent to which Freedom contributed to the calculation of the Happiness Score.
# *  **Corruption** The extent to which Perception of Corruption contributes to Happiness Score.
# *  **Generosity** The extent to which Generosity contributed to the calculation of the Happiness Score.
# *  **Log of GDP per capita** The extent to which GDP contributes to the calculation of the Happiness Score.
# *  **Healthy life expectancy** The extent to which Life expectancy contributed to the calculation of the Happiness Score.

# %% [markdown]
# Посмотреть первые несколько рядов таблицы

# %%
df.head()
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# 1                      23.0
# 2                      12.0
# 3                      13.0
# 4                      18.0

# %% [markdown]
# Построить частотный график для двух параметров: Freedom и positive affect. Какое это распределение?

# %%
plt.hist(df['Freedom'],70, facecolor='r')
plt.grid(True)
plt.title('Frequency chart Freedom')
plt.xlabel('Freedom')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Positive affect'], 70, facecolor='r')
plt.grid(True)
plt.title('Frequency chart Positive affect')
plt.xlabel('Positive affect')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Равномерное распределение и графики для двух разных показателей выглядят практически одинаково

# %% [markdown]
# Найти медиану, моду, математическое ожидание, стандартное отклонение,  дисперсию, минимум и максимум, найти выбросы (если есть), размах для колонки Freedom

# %%
# Выбросы
df['Freedom'].isnull().sum()
# Out:
# 1

# %%
# Заполним nan 
df['Freedom'].fillna(0, inplace = True)
df['Positive affect'].fillna(0, inplace = True)

# %%
print('Медиана =', statistics.median(df['Freedom']))
print('Мода =', statistics.mode(df['Freedom']))
print('Мат ожидание =', statistics.mean(df['Freedom']))
print('Стандартное отклонение =', statistics.pstdev(df['Freedom']))
print('Дисперсия =', statistics.pvariance(df['Freedom']))
print('Минимум =', min(df['Freedom']))
print('Максимум =', max(df['Freedom']))
print('Размах =', max(df['Freedom']) - min(df['Freedom']))
# Out:
# Медиана = 77.5
# Мода = 5.0
# Мат ожидание = 77.5
# Стандартное отклонение = 45.032395746469746
# Дисперсия = 2027.9166666666667
# Минимум = 0.0
# Максимум = 155.0
# Размах = 155.0

# %% [markdown]
# Почему нельзя найти моду?

# %% [markdown]
# Из-за сильного разброса она будет неверной

# %% [markdown]
# Посмотреть корреляцию между Freedom и positive affect (графически и математически). Графически - plt.scatter, математически - посчитать коэффициент Пирсона. О чем говорит знак коэффициента?

# %%
x = df['Freedom']
y = df['Positive affect']

plt.scatter(x, y)
plt.title('Correlation')
plt.xlabel('Freedom')
plt.ylabel('Positive affect')
plt.show()

# %%
corr, _ = sts.pearsonr(x, y)
print(f'Коэффициент Пирсона {corr}')
# Out:
# Коэффициент Пирсона 0.6878506740844936

# %% [markdown]
# 68% - средняя зависимость между переменными

# %% [markdown]
# Нормализовать данные колонки Freedom (централизация + масштабирование)

# %%
Freedom = df['Freedom']
print(statistics.mean(Freedom))

Freedom_1 = Freedom - statistics.mean(Freedom)
print(statistics.mean(Freedom_1))
# Out:
# 77.5
# 0.0

# %%
min(Freedom_1)
# Out:
# -77.5

# %%
max(Freedom_1)
# Out:
# 77.5

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler(feature_range=(-1,1))

Freedom_2 = min_max_scaler.fit_transform(np.array(Freedom_1).reshape(-1, 1))
print(min(Freedom_2))
print(max(Freedom_2))
# Out:
# [-1.]
# [1.]

# %% [markdown]
# Построить матрицу корреляций для всех колонок таблицы

# %%
import seaborn as sns
sns.heatmap(df.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) 
fig=plt.gcf()
fig.set_size_inches(12,12)
plt.show()

# %% [markdown]
# Загрузить таблицу цен на авокадо:

# %%
df=pd.read_csv('avocado.csv')
df[:3]
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany

# %% [markdown]
# Сделать частотный график колонки AveragePrice. Какое это распределение?

# %%
plt.hist(df['AveragePrice'], 50)
plt.title('Frequency AveragePrice')
plt.xlabel('AveragePrice')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# Нормальное распределение

# %% [markdown]
# Найти корреляцию в следующих колонках:

# %% [markdown]
# колонкой 4046, 4225, 4770 и Average Price. Если корелляция есть (обратная или прямая), то какие выводы можно сделать?

# %%
x_col_name = '4046'
y_col_name = 'AveragePrice'

x = df[x_col_name]
y = df[y_col_name]

plt.figure(figsize=(10, 7))
plt.scatter(x, y, marker='x')
corr = df[x_col_name].corr(df[y_col_name])
print('Коэффициент Пирсона =', corr)
# Out:
# Коэффициент Пирсона = -0.20831704848788465

# %%
x_col_name = '4225'
y_col_name = 'AveragePrice'

x = df[x_col_name]
y = df[y_col_name]

plt.figure(figsize=(10, 7))
plt.scatter(x, y, marker='x')
corr = df[x_col_name].corr(df[y_col_name])
print('Коэффициент Пирсона =', corr)
# Out:
# Коэффициент Пирсона = -0.17292777250933547

# %%
x_col_name = '4770'
y_col_name = 'AveragePrice'

x = df[x_col_name]
y = df[y_col_name]

plt.figure(figsize=(10, 7))
plt.scatter(x, y, marker='x')
corr = df[x_col_name].corr(df[y_col_name])
print('Коэффициент Пирсона =', corr)
# Out:
# Коэффициент Пирсона = -0.17944598397975614

# %% [markdown]
# Корреляция обратная. При увеличении значений колонок средняя цена будет снижаться.
